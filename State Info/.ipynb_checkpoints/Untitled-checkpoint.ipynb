# %%
import pandas as pd

# %%
df= pd.read_csv("State_Info.csv")

# %%
df.head()
# Out:
#          Name  Electoral Votes  Registered Voters  Population  \
# 0     Alabama                9            2490000     4908620
# 1      Alaska                3             337000      734002
# 2     Arizona               11            3262000     7378490
# 3    Arkansas                6            1262000     3039000
# 4  California               55           15690000    39937500
#
#   Percentage of Population Party plurality               2016 Results  \
# 0                   50.73%      Republican   Republican: Donald Trump
# 1                   45.91%      Republican   Republican: Donald Trump
# 2                   44.21%      Republican   Republican: Donald Trump
# 3                   41.53%      Republican   Republican: Donald Trump
# 4                   39.29%      Democratic  Democrat: Hillary Clinton
#
#               2012 Results             2008 Results  \
# 0  Republican: Mitt Romney  Republican: John McCain
# 1  Republican: Mitt Romney  Republican: John McCain
# ...

# %%
df.to_json("State_Info.json")
