# %%
import pandas as pd

# %%
df= pd.read_csv("State Info_1.csv")

# %%
df.head()
# Out:
#                          id     Alabama      Alaska     Arizona    Arkansas  \
# 0           Electoral Votes           9           3          11           6
# 1         Registered Voters     2490000      337000     3262000     1262000
# 2                Population     4908620      734002     7378490     3039000
# 3  Percentage of Population      50.73%      45.91%      44.21%      41.53%
# 4           Party plurality  Republican  Republican  Republican  Republican
#
#    California    Colorado Connecticut    Delaware District of Columbia  ...  \
# 0          55           9           7           3                    3  ...
# 1    15690000     2645000     1726000      472000               500675  ...
# 2    39937500     5845530     3563080      982895               705749  ...
# 3      39.29%      45.25%      48.44%      48.02%               70.94%  ...
# 4  Democratic  Democratic  Democratic  Democratic           Democratic  ...
#
# ...

# %%
df.set_index("id",inplace=True)

# %%
df.head()
# Out:
#                              Alabama      Alaska     Arizona    Arkansas  \
# id
# Electoral Votes                    9           3          11           6
# Registered Voters            2490000      337000     3262000     1262000
# Population                   4908620      734002     7378490     3039000
# Percentage of Population      50.73%      45.91%      44.21%      41.53%
# Party plurality           Republican  Republican  Republican  Republican
#
#                           California    Colorado Connecticut    Delaware  \
# id
# Electoral Votes                   55           9           7           3
# Registered Voters           15690000     2645000     1726000      472000
# Population                  39937500     5845530     3563080      982895
# Percentage of Population      39.29%      45.25%      48.44%      48.02%
# Party plurality           Democratic  Democratic  Democratic  Democratic
#
# ...

# %%
polls_df=pd.read_csv("Polls.csv")

# %%
polls_df.head()
# Out:
#            Name  Alabama  Alaska  Arizona  Arkansas  California  Colorado  \
# 0     Joe Biden     39.0    40.0     47.1      45.0        58.0      56.0
# 1  Donald Trump     53.0    45.0     45.4      47.0        30.0      39.0
# 2     Undecided      8.0    15.0      7.5       8.0        12.0       5.0
# 3           NaN      NaN     NaN      NaN       NaN         NaN       NaN
# 4           NaN      NaN     NaN      NaN       NaN         NaN       NaN
#
#    Connecticut  Delaware  District of Columbia  ...  South Dakota  Tennessee  \
# 0         55.9      45.9                  96.2  ...          40.0       42.0
# 1         33.0      40.2                   3.8  ...          60.0       51.0
# 2         11.1      13.9                   0.0  ...           0.0        7.0
# 3          NaN       NaN                   NaN  ...           NaN        NaN
# 4          NaN       NaN                   NaN  ...           NaN        NaN
#
# ...

# %%
polls_df.set_index("Name", inplace=True)

# %%
polls_json=polls_df.head(3)
